# %% [markdown]
# # Python Basics
#
# ## Today
#
# We will learn how to:
#
# - Create and use variables
# - Work with basic Python types
# - Use built-in functions
# - Perform numerical calculations
# - Work with text (strings)
# - Make comparisons using booleans
# - Begin working with collections if time allows
#
# > **Focus on understanding what the code does. You do not need to memorize every command.**

# %% [markdown]
# ## 1. Variable Assignment
#
# Variable assignment associates a value with a variable.
#
# A variable is a name that we can use to refer to a value.

# %%
# Type the code from the lecture here.
x = "Hello Python"

# %% [markdown]
# Once we assign a value to a variable, Python remembers that variable **during the current Python session**.

# %%
x
print(x)
# Out:
# Hello Python

# %% [markdown]
# What happens if we use a variable that has not been created yet?
#
# Run the next cell and read the error message.

# %%
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(y)
#
# NameError: name 'y' is not defined

# %% [markdown]
# We can assign a different value to an existing variable.

# %%
# Type the code from the lecture here.
x = 1

# %%
x = "Something else"
print(x)
x
# Out:
# Something else
# 'Something else'

# %% [markdown]
# ### Your turn
#
# A product sells for **$12.50** and **80 units** are sold.
#
# Create variables named `price` and `quantity`, then calculate total `revenue`.

# %%
# Write your code here.
price = 12.5
quantity = 80
print(f"Revenue = ${price * quantity:.2f} Dollars")
# Out:
# Revenue = $1000.00 Dollars

# %% [markdown]
# ### Code Comments
#
# Comments are useful for leaving short notes for yourself or other programmers.
#
# A comment starts with `#`. Python ignores everything after `#` on that line.

# %%
# Write your code here.
i = 2 #Assign the value 2 to the variable i
j = 5 #Assign the value 5 to the variable j

#multiply the two variables and assign the result to a new variable called k
k = i * j

# %% [markdown]
# ## 2. Functions
#
# A function is a reusable piece of code that performs an operation. It may take **inputs (arguments)** and produce an **output**.
#
# We have already used the `print()` function.

# %%
# Type the code from the lecture here.
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %% [markdown]
# ### Finding help
#
# You do not need to memorize every function. Python and Jupyter can help you find information.
#
# Try asking Jupyter what `print` does:

# %% [markdown]
# For example, what does the `len()` function do?

# %%
len

# %%
l

# %% [markdown]
# ### Asking the user for input
#
# The `input()` function pauses the program and waits for the user to enter something.
#
# **Important:** `input()` returns a **string**.

# %%
# Type the code from the lecture here.
s

# %% [markdown]
# We will learn much more about writing our own functions later in the course.

# %% [markdown]
# ## 3. Types and Methods
#
# Every value in Python has a **type**.
#
# The type tells Python what kind of data the value represents and what operations are available.

# %%
# Type the code from the lecture here.

# %% [markdown]
# Some types have **methods**: functions associated with that object.
#
# Use the dot `.` to explore what an object can do. In Jupyter, type `x.` and press **Tab** to see available methods.

# %%
# Type the code from the lecture here.

# %% [markdown]
# > **Programming habit:** When you get stuck, inspect the object and use documentation rather than trying to memorize everything.

# %% [markdown]
# ## 4. Modules and Packages
#
# Python's functionality is organized into modules and packages. We can import these tools when we need them.
#
# Some packages we will use later:
#
# - `numpy` — numerical computing
# - `pandas` — data analysis
# - `matplotlib` — visualization

# %%
# Type the code from the lecture here.

# %% [markdown]
# A module can have a long name, so we often use a short **alias**.
#
# For example:

# %% [markdown]
# Now we can refer to NumPy as `np`. We will use this convention throughout the course.

# %% [markdown]
# ## 5. Numbers
#
# Python has several numerical types. Two that we will use frequently are:
#
# - `int` — integers
# - `float` — numbers with decimal points

# %%
# Type the code from the lecture here.

# %% [markdown]
# ### Arithmetic operations
#
# Python supports the usual arithmetic operations:
#
# `+` addition
# `-` subtraction
# `*` multiplication
# `/` division
# `**` exponentiation

# %%
# Type the code from the lecture here.

# %% [markdown]
# ### A library function
#
# What happens if we try to use `sin()` without importing a library?

# %%
sin(3)

# %% [markdown]
# The error tells us that Python does not know what `sin` means yet.
#
# Import the `math` module and use `math.sin()`.

# %%
# Type the code from the lecture here.

# %% [markdown]
# ### Division, floor division, and remainder
#
# Before running the next cell, predict each result.
#
# - `/` — regular division
# - `//` — floor division
# - `%` — remainder

# %%
# Type the code from the lecture here.

# %% [markdown]
# ### Economic example
#
# Let `principal = 1000` and `interest_rate = 0.05`. Calculate the value after one period.

# %%
# Type the code from the lecture here.

# %% [markdown]
# ## 6. Strings
#
# A **string** is a data type used to store text.
#
# Strings are written inside quotation marks (`"..."` or `'...'`).

# %%
# Type the code from the lecture here.

# %% [markdown]
# The next examples are intentionally incorrect. Run them and inspect the error message.

# %% [markdown]
# Quotation marks can also create a problem when the quote character appears inside the string. One way to fix it is to use different quotation marks around the string.

# %%
'What's wrong with this string'

# %% [markdown]
# ### String operations
#
# Strings can be combined and repeated.
#
# - `a + b` puts strings together
# - `n * a` repeats a string `n` times

# %%
# Type the code from the lecture here.

# %% [markdown]
# ### Pop Quiz
#
# How could you create the sentence `Hello UConn`?
#
# **Hint:** How can we represent a space as a string?

# %%
c = " "
a + c + b

# %% [markdown]
# What do you expect the following to do?
#
# `a * b`

# %% [markdown]
# ## String Formatting
#
# We often need to insert variable values into text. **f-strings** are the modern and readable way to do this.

# %%
# Type the code from the lecture here.

# %%
# Converting GDP from billions of dollars to dollars

# %% [markdown]
# ### Your turn — 2 minutes
#
# Suppose:
#
# ```python
# country = "USA"
# year = 2026
# inflation = 2.5
# ```
#
# Use an f-string to print:
#
# > Inflation in USA was 2.5% in 2026.

# %%
# Write your code here.

# %% [markdown]
# You may encounter the older `.format()` method in existing code, but for this course we will mainly use **f-strings**.

# %% [markdown]
# # 7. Booleans
#
# A **boolean** is a value that is either `True` or `False`.

# %%
# Type the code from the lecture here.

# %% [markdown]
# Instead of writing `True` or `False` directly, we often create booleans by making a comparison.

# %%
# Type the code from the lecture here.

# %% [markdown]
# ### `and`, `or`, and `not`
#
# These operators combine or reverse boolean conditions.

# %%
# Type the code from the lecture here.

# %% [markdown]
# For example, `and` is true only when **both** conditions are true, while `or` is true when **at least one** condition is true.

# %% [markdown]
# ### Note on `all()` and `any()`
#
# These functions return a single boolean from a collection of boolean values.
#
# - `all(...)` is `True` when every value is true.
# - `any(...)` is `True` when at least one value is true.

# %% [markdown]
# ### Your turn — Predict before running
#
# Which expressions are `True`?

# %%
price = 12
quantity = 80

print(price > 10)
print(quantity >= 100)
print((price > 10) and (quantity < 100))

# %% [markdown]
# # Exercises
#
# ## Q1. Greeting
#
# Write a program that uses `input()` to prompt a user for their name and then welcomes them.
#
# Example:
#
# ```text
# Enter your name: Husky
# Hello Husky
# ```
#
# Try writing the solution yourself before looking at any example.

# %%
# Write your code here.

# %% [markdown]
# ## Q2. Gross pay
#
# Write a program to prompt the user for hours worked and rate per hour, then compute gross pay.
#
# Example:
#
# ```text
# Enter Hours: 20
# Enter Rate: 3.5
# Pay: 70
# ```
#
# Notice that `input()` returns strings. Convert the values to numbers before doing arithmetic.

# %%
# Write your code here.
